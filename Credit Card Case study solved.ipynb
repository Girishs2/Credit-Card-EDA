# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
cust_acq = pd.read_csv(r"E:\Assignments\Python Foundation Case Study 2 - Credit Card Case Study\Customer Acqusition.csv")

# %%
cust_acq
# Out:
#      No Customer  Age        City   Product     Limit Company        Segment
# 0     1       A1   76   BANGALORE      Gold  500000.0      C1  Self Employed
# 1     2       A2   71    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2     3       A3   34      COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3     4       A4   47      BOMBAY  Platimum   10001.0      C4           Govt
# 4     5       A5   56   BANGALORE  Platimum   10002.0      C5  Normal Salary
# ..  ...      ...  ...         ...       ...       ...     ...            ...
# 95   96      A96   54     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 96   97      A97   58  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 97   98      A98   51    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 98   99      A99   35    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 99  100     A100   36      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# [100 rows x 8 columns]

# %%
Repayment = pd.read_csv(r"E:\Assignments\Python Foundation Case Study 2 - Credit Card Case Study\Repayment.csv")

# %%
Repayment
# Out:
#       SL No: Customer      Month     Amount  Unnamed: 4
# 0        NaN       A1  12-Jan-04  495414.75         NaN
# 1        2.0       A1   3-Jan-04  245899.02         NaN
# 2        3.0       A1  15-Jan-04  259490.06         NaN
# 3        4.0       A1  25-Jan-04  437555.12         NaN
# 4        5.0       A1  17-Jan-05  165972.88         NaN
# ...      ...      ...        ...        ...         ...
# 1518     NaN      NaN        NaN        NaN         NaN
# 1519     NaN      NaN        NaN        NaN         NaN
# 1520     NaN      NaN        NaN        NaN         NaN
# 1521     NaN      NaN        NaN        NaN         NaN
# 1522     NaN      NaN        NaN        NaN         NaN
#
# [1523 rows x 5 columns]

# %%
spend = pd.read_csv(r"E:\Assignments\Python Foundation Case Study 2 - Credit Card Case Study\spend.csv")

# %%
spend
# Out:
#       Sl No: Customer      Month        Type     Amount
# 0          1       A1  12-Jan-04   JEWELLERY  485470.80
# 1          2       A1   3-Jan-04       PETRO  410556.13
# 2          3       A1  15-Jan-04     CLOTHES   23740.46
# 3          4       A1  25-Jan-04        FOOD  484342.47
# 4          5       A1  17-Jan-05      CAMERA  369694.07
# ...      ...      ...        ...         ...        ...
# 1495    1496      A67   4-Feb-06  BUS TICKET  356872.73
# 1496    1497      A68  25-Mar-06  BUS TICKET  204971.10
# 1497    1498      A69  31-Mar-06  BUS TICKET   50449.44
# 1498    1499      A70  23-Mar-06  BUS TICKET   80593.94
# 1499    1500      A71  24-Mar-06  BUS TICKET  194447.62
#
# [1500 rows x 5 columns]

# %%
cust_acq.drop(columns=['No'], axis=1, inplace=True)

# %%
cust_acq.head(2)
# Out:
#   Customer  Age       City Product     Limit Company        Segment
# 0       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A2   71   CALCUTTA  Silver  100000.0      C2   Salaried_MNC

# %%
Repayment.drop(columns=['SL No:','Unnamed: 4'], axis=1, inplace=True)

# %%
Repayment.head()
# Out:
#   Customer      Month     Amount
# 0       A1  12-Jan-04  495414.75
# 1       A1   3-Jan-04  245899.02
# 2       A1  15-Jan-04  259490.06
# 3       A1  25-Jan-04  437555.12
# 4       A1  17-Jan-05  165972.88

# %%
spend.drop(columns='Sl No:', axis=1, inplace=True)

# %%
spend.head()
# Out:
#   Customer      Month       Type     Amount
# 0       A1  12-Jan-04  JEWELLERY  485470.80
# 1       A1   3-Jan-04      PETRO  410556.13
# 2       A1  15-Jan-04    CLOTHES   23740.46
# 3       A1  25-Jan-04       FOOD  484342.47
# 4       A1  17-Jan-05     CAMERA  369694.07

# %%
cust_acq.shape
# Out:
# (100, 7)

# %%
Repayment.shape
# Out:
# (1523, 3)

# %%
spend.shape
# Out:
# (1500, 4)

# %%
cust_acq.dtypes
# Out:
# Customer     object
# Age           int64
# City         object
# Product      object
# Limit       float64
# Company      object
# Segment      object
# dtype: object

# %%
Repayment.dtypes
# Out:
# Customer     object
# Month        object
# Amount      float64
# dtype: object

# %%
spend.dtypes
# Out:
# Customer     object
# Month        object
# Type         object
# Amount      float64
# dtype: object

# %%
cust_acq.isna().sum()
# Out:
# Customer    0
# Age         0
# City        0
# Product     0
# Limit       0
# Company     0
# Segment     0
# dtype: int64

# %%
spend.isna().sum()
# Out:
# Customer    0
# Month       0
# Type        0
# Amount      0
# dtype: int64

# %%
Repayment.isna().sum()
# Out:
# Customer    23
# Month       23
# Amount      23
# dtype: int64

# %%
Repayment.dropna(inplace=True)

# %%
Repayment.isna().sum()
# Out:
# Customer    0
# Month       0
# Amount      0
# dtype: int64

# %% [markdown]
# 1. In the above dataset,
#
# a. In case age is less than 18, replace it with mean of age values.

# %%
cust_acq.Age.unique()
# Out:
# array([76, 71, 34, 47, 56, 70, 26, 67, 79, 54, 35, 51, 29, 16, 25, 52, 78,
#        27, 57, 53, 38, 24, 36, 72, 63, 41, 19, 55, 60, 61, 37, 13, 50, 21,
#        28, 49, 42, 39, 69, 59, 46, 43, 32, 74, 44, 15, 77, 12, 33, 75, 66,
#        65, 31, 62, 58], dtype=int64)

# %%
cust_acq['Age'].mean()
# Out:
# 46.49

# %%
cust_acq.loc[cust_acq['Age']<18,'Age']=cust_acq['Age'].mean()
cust_acq
# Out:
#    Customer   Age        City   Product     Limit Company        Segment
# 0        A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 1        A2  71.0    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2        A3  34.0      COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3        A4  47.0      BOMBAY  Platimum   10001.0      C4           Govt
# 4        A5  56.0   BANGALORE  Platimum   10002.0      C5  Normal Salary
# ..      ...   ...         ...       ...       ...     ...            ...
# 95      A96  54.0     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 96      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 97      A98  51.0    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 98      A99  35.0    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 99     A100  36.0      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# [100 rows x 7 columns]

# %%
cust_acq.Age.unique() <18
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False])

# %% [markdown]
#  b. In case spend amount is more than the limit, replace it with 50% of that customer’s limit.
#
# (customer’s limit provided in acquisition table is the per transaction limit on his card)

# %%
spend.head(2)
# Out:
#   Customer      Month       Type     Amount
# 0       A1  12-Jan-04  JEWELLERY  485470.80
# 1       A1   3-Jan-04      PETRO  410556.13

# %%
cust_acq.head(2)
# Out:
#   Customer   Age       City Product     Limit Company        Segment
# 0       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A2  71.0   CALCUTTA  Silver  100000.0      C2   Salaried_MNC

# %%
print(spend.shape)
print(cust_acq.shape)
# Out:
# (1500, 4)
# (100, 7)

# %%
cust_spend = pd.merge(left=cust_acq, right=spend, on='Customer', how='outer')

# %%
cust_spend
# Out:
#      Customer   Age        City   Product     Limit Company        Segment  \
# 0          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 1          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 2          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 3          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 4          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# ...       ...   ...         ...       ...       ...     ...            ...
# 1495      A96  54.0     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 1496      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 1497      A98  51.0    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 1498      A99  35.0    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 1499     A100  36.0      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
#           Month        Type     Amount
# ...

# %%
cust_spend.loc[cust_spend['Amount']>cust_spend['Limit'], 'Amount'] = cust_spend['Limit']/2

# %%
cust_spend
# Out:
#      Customer   Age        City   Product     Limit Company        Segment  \
# 0          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 1          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 2          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 3          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 4          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# ...       ...   ...         ...       ...       ...     ...            ...
# 1495      A96  54.0     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 1496      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 1497      A98  51.0    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 1498      A99  35.0    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 1499     A100  36.0      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
#           Month        Type     Amount
# ...

# %% [markdown]
# c. Incase the repayment amount is more than the limit, replace the repayment with the
# limit.

# %%
Repayment.head(2)
# Out:
#   Customer      Month     Amount
# 0       A1  12-Jan-04  495414.75
# 1       A1   3-Jan-04  245899.02

# %%
cust_acq.head(2)
# Out:
#   Customer   Age       City Product     Limit Company        Segment
# 0       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A2  71.0   CALCUTTA  Silver  100000.0      C2   Salaried_MNC

# %%
cust_repay = pd.merge(left=cust_acq, right=Repayment, on = 'Customer', how = 'outer')

# %%
cust_repay
# Out:
#      Customer   Age        City   Product     Limit Company        Segment  \
# 0          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 1          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 2          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 3          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 4          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# ...       ...   ...         ...       ...       ...     ...            ...
# 1495      A96  54.0     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 1496      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 1497      A98  51.0    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 1498      A99  35.0    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 1499     A100  36.0      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
#           Month     Amount
# 0     12-Jan-04  495414.75
# ...

# %%
cust_repay.loc[cust_repay['Amount']>cust_repay['Limit'], 'Amount'] = cust_repay['Limit']

# %%
cust_repay
# Out:
#      Customer   Age        City   Product     Limit Company        Segment  \
# 0          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 1          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 2          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 3          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 4          A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# ...       ...   ...         ...       ...       ...     ...            ...
# 1495      A96  54.0     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 1496      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 1497      A98  51.0    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 1498      A99  35.0    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 1499     A100  36.0      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
#           Month     Amount
# 0     12-Jan-04  495414.75
# ...

# %% [markdown]
# 2. From the above dataset create the following summaries:
#
#  a. How many distinct customers exist?

# %%
cust_acq.Customer.value_counts().sum()
# Out:
# 100

# %% [markdown]
# b. How many distinct categories exist?

# %%
cust_acq.Segment.nunique()
# Out:
# 5

# %% [markdown]
#  c. What is the average monthly spend by customers?

# %%
spend
# Out:
#      Customer      Month        Type     Amount
# 0          A1  12-Jan-04   JEWELLERY  485470.80
# 1          A1   3-Jan-04       PETRO  410556.13
# 2          A1  15-Jan-04     CLOTHES   23740.46
# 3          A1  25-Jan-04        FOOD  484342.47
# 4          A1  17-Jan-05      CAMERA  369694.07
# ...       ...        ...         ...        ...
# 1495      A67   4-Feb-06  BUS TICKET  356872.73
# 1496      A68  25-Mar-06  BUS TICKET  204971.10
# 1497      A69  31-Mar-06  BUS TICKET   50449.44
# 1498      A70  23-Mar-06  BUS TICKET   80593.94
# 1499      A71  24-Mar-06  BUS TICKET  194447.62
#
# [1500 rows x 4 columns]

# %%
spend.dtypes
# Out:
# Customer     object
# Month        object
# Type         object
# Amount      float64
# dtype: object

# %%
spend['Month'] = pd.to_datetime(spend['Month'])

# %%
spend.dtypes
# Out:
# Customer            object
# Month       datetime64[ns]
# Type                object
# Amount             float64
# dtype: object

# %%
import datetime as dt

# %%
spend['monthly'] = spend['Month'].apply(lambda x:dt.datetime.strftime(x, format='%B') )
spend['Yearly'] = spend['Month'].apply(lambda x:dt.datetime.strftime(x, format='%Y') )

# %%
spend
# Out:
#      Customer      Month        Type     Amount   monthly Yearly
# 0          A1 2004-01-12   JEWELLERY  485470.80   January   2004
# 1          A1 2004-01-03       PETRO  410556.13   January   2004
# 2          A1 2004-01-15     CLOTHES   23740.46   January   2004
# 3          A1 2004-01-25        FOOD  484342.47   January   2004
# 4          A1 2005-01-17      CAMERA  369694.07   January   2005
# ...       ...        ...         ...        ...       ...    ...
# 1495      A67 2006-02-04  BUS TICKET  356872.73  February   2006
# 1496      A68 2006-03-25  BUS TICKET  204971.10     March   2006
# 1497      A69 2006-03-31  BUS TICKET   50449.44     March   2006
# 1498      A70 2006-03-23  BUS TICKET   80593.94     March   2006
# 1499      A71 2006-03-24  BUS TICKET  194447.62     March   2006
#
# [1500 rows x 6 columns]

# %%
avg_spend = spend.groupby(['Yearly', 'monthly']).mean()

# %%
avg_spend
# Out:
#                          Amount
# Yearly monthly
# 2004   April      235272.037143
#        February   221215.270000
#        January    251712.068664
#        March      232146.119286
#        May        217539.236429
#        November   270486.397857
#        September  310923.383571
# 2005   April      252181.326429
#        August     233734.634286
#        December   147503.060000
#        February   229802.279821
#        January    292741.372857
#        July       229116.663571
#        June       262688.112857
#        May        245696.515429
#        November   286143.322857
#        October    194568.640714
#        September  188666.202143
# 2006   April      232468.967553
#        August     240699.717143
#        December   270470.980714
#        February   253858.260714
#        January    282058.006429
#        July       287505.098929
#        June       177252.386429
#        March      247166.084654
#        May        236162.740357
# ...

# %% [markdown]
#  d. What is the average monthly repayment by customers?

# %%
Repayment.head()
# Out:
#   Customer      Month     Amount
# 0       A1  12-Jan-04  495414.75
# 1       A1   3-Jan-04  245899.02
# 2       A1  15-Jan-04  259490.06
# 3       A1  25-Jan-04  437555.12
# 4       A1  17-Jan-05  165972.88

# %%
Repayment.dtypes
# Out:
# Customer     object
# Month        object
# Amount      float64
# dtype: object

# %%
Repayment['Month']= pd.to_datetime(Repayment['Month'])

# %%
Repayment.dtypes
# Out:
# Customer            object
# Month       datetime64[ns]
# Amount             float64
# dtype: object

# %%
Repayment['monthly'] = Repayment['Month'].apply(lambda x: dt.datetime.strftime(x, format = '%B'))
Repayment['Yearly'] = Repayment['Month'].apply(lambda x : dt.datetime.strftime(x, format='%Y'))

# %%
Repayment.head(3)
# Out:
#   Customer      Month     Amount  monthly Yearly
# 0       A1 2004-01-12  495414.75  January   2004
# 1       A1 2004-01-03  245899.02  January   2004
# 2       A1 2004-01-15  259490.06  January   2004

# %%
avg_repay = Repayment.groupby(['Yearly','monthly']).mean().round(2)

# %%
avg_repay
# Out:
#                      Amount
# Yearly monthly
# 2004   April      259141.68
#        February   256702.63
#        January    243489.65
#        March      252585.28
#        May        226162.72
#        November   209592.24
#        September  184487.85
# 2005   April      212688.63
#        August     264430.92
#        December   320379.34
#        February   238829.27
#        January    240548.10
#        July       239871.48
#        June       210199.82
#        May        263207.37
#        November   256695.12
#        October    219849.96
#        September  247700.17
# 2006   April      275472.25
#        August     224143.99
#        December   252736.57
#        February   284489.57
#        January    293475.39
#        July       257936.38
#        June       251990.45
#        March      240851.27
#        May        256920.88
#        November   199399.20
#        October    260765.48
#        September  262533.88

# %% [markdown]
#  e. If the monthly rate of interest is 2.9%, what is the profit for the bank for each month?
#
# (Profit is defined as interest earned on Monthly Profit. Monthly Profit = Monthly repayment
# – Monthly spend. Interest is earned only on positive profits and not on negative amounts)

# %%
cust_spend.head()
# Out:
#   Customer   Age       City Product     Limit Company        Segment  \
# 0       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month       Type     Amount
# 0  12-Jan-04  JEWELLERY  485470.80
# 1   3-Jan-04      PETRO  410556.13
# 2  15-Jan-04    CLOTHES   23740.46
# 3  25-Jan-04       FOOD  484342.47
# 4  17-Jan-05     CAMERA  369694.07

# %%
Repayment.head()
# Out:
#   Customer      Month     Amount  monthly Yearly
# 0       A1 2004-01-12  495414.75  January   2004
# 1       A1 2004-01-03  245899.02  January   2004
# 2       A1 2004-01-15  259490.06  January   2004
# 3       A1 2004-01-25  437555.12  January   2004
# 4       A1 2005-01-17  165972.88  January   2005

# %%
cust_spend.head(2)
# Out:
#   Customer   Age       City Product     Limit Company        Segment  \
# 0       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month       Type     Amount
# 0  12-Jan-04  JEWELLERY  485470.80
# 1   3-Jan-04      PETRO  410556.13

# %%
Repayment.head(2)
# Out:
#   Customer      Month     Amount  monthly Yearly
# 0       A1 2004-01-12  495414.75  January   2004
# 1       A1 2004-01-03  245899.02  January   2004

# %%
Repayment.head(2)
# Out:
#   Customer      Month     Amount  monthly Yearly
# 0       A1 2004-01-12  495414.75  January   2004
# 1       A1 2004-01-03  245899.02  January   2004

# %%
cust_spend_repay = pd.merge(left=cust_spend, right=Repayment, on='Customer', how='inner')

# %%
cust_spend_repay.head()
# Out:
#   Customer   Age       City Product     Limit Company        Segment  \
# 0       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#      Month_x       Type  Amount_x    Month_y   Amount_y  monthly Yearly
# 0  12-Jan-04  JEWELLERY  485470.8 2004-01-12  495414.75  January   2004
# 1  12-Jan-04  JEWELLERY  485470.8 2004-01-03  245899.02  January   2004
# 2  12-Jan-04  JEWELLERY  485470.8 2004-01-15  259490.06  January   2004
# 3  12-Jan-04  JEWELLERY  485470.8 2004-01-25  437555.12  January   2004
# 4  12-Jan-04  JEWELLERY  485470.8 2005-01-17  165972.88  January   2005

# %%
cust_spend_repay.rename(columns={'Amount_x':'spend_amount', 'Amount_y':'repay_amount'}, inplace=True)

# %%
cust_spend.head(1)
# Out:
#   Customer   Age       City Product     Limit Company        Segment  \
# 0       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month       Type    Amount
# 0  12-Jan-04  JEWELLERY  485470.8

# %%
spend_repay_grp = cust_spend_repay.groupby(['Yearly','monthly'])['spend_amount','repay_amount'].sum()
# Out:
# C:\Users\Girish\AppData\Local\Temp/ipykernel_24412/2594957422.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   spend_repay_grp = cust_spend_repay.groupby(['Yearly','monthly'])['spend_amount','repay_amount'].sum()

# %%
spend_repay_grp
# Out:
#                   spend_amount  repay_amount
# Yearly monthly
# 2004   April      1.194516e+08  2.285403e+08
#        February   7.613922e+07  1.602419e+08
#        January    1.088357e+09  1.699210e+09
#        March      5.594171e+07  8.974470e+07
#        May        8.800456e+07  1.411594e+08
#        November   5.504612e+07  7.860290e+07
#        September  5.144278e+07  8.016122e+07
# 2005   April      9.366405e+07  1.747894e+08
#        August     1.361400e+08  2.477449e+08
#        December   4.348638e+07  9.944533e+07
#        February   5.890557e+08  9.416163e+08
#        January    1.324129e+08  1.810333e+08
#        July       3.995653e+07  7.997268e+07
#        June       1.174019e+08  2.213774e+08
#        May        7.149030e+08  1.099197e+09
#        November   1.532278e+08  2.763119e+08
#        October    3.140993e+07  6.027830e+07
#        September  3.195551e+07  7.530449e+07
# 2006   April      3.229722e+08  6.093666e+08
# ...

# %%
spend_repay_grp['Monthly_profit'] = spend_repay_grp['repay_amount'] - spend_repay_grp['spend_amount']

# %%
spend_repay_grp
# Out:
#                   spend_amount  repay_amount  Monthly_profit
# Yearly monthly
# 2004   April      1.194516e+08  2.285403e+08    1.090887e+08
#        February   7.613922e+07  1.602419e+08    8.410268e+07
#        January    1.088357e+09  1.699210e+09    6.108525e+08
#        March      5.594171e+07  8.974470e+07    3.380298e+07
#        May        8.800456e+07  1.411594e+08    5.315485e+07
#        November   5.504612e+07  7.860290e+07    2.355678e+07
#        September  5.144278e+07  8.016122e+07    2.871844e+07
# 2005   April      9.366405e+07  1.747894e+08    8.112539e+07
#        August     1.361400e+08  2.477449e+08    1.116049e+08
#        December   4.348638e+07  9.944533e+07    5.595895e+07
#        February   5.890557e+08  9.416163e+08    3.525606e+08
#        January    1.324129e+08  1.810333e+08    4.862042e+07
#        July       3.995653e+07  7.997268e+07    4.001615e+07
#        June       1.174019e+08  2.213774e+08    1.039755e+08
# ...

# %%
spend_repay_grp['interest_earned'] = (2.9 * spend_repay_grp['Monthly_profit'])/100

# %%
spend_repay_grp
# Out:
#                   spend_amount  repay_amount  Monthly_profit  interest_earned
# Yearly monthly
# 2004   April      1.194516e+08  2.285403e+08    1.090887e+08     3.163572e+06
#        February   7.613922e+07  1.602419e+08    8.410268e+07     2.438978e+06
#        January    1.088357e+09  1.699210e+09    6.108525e+08     1.771472e+07
#        March      5.594171e+07  8.974470e+07    3.380298e+07     9.802865e+05
#        May        8.800456e+07  1.411594e+08    5.315485e+07     1.541491e+06
#        November   5.504612e+07  7.860290e+07    2.355678e+07     6.831466e+05
#        September  5.144278e+07  8.016122e+07    2.871844e+07     8.328349e+05
# 2005   April      9.366405e+07  1.747894e+08    8.112539e+07     2.352636e+06
#        August     1.361400e+08  2.477449e+08    1.116049e+08     3.236542e+06
#        December   4.348638e+07  9.944533e+07    5.595895e+07     1.622810e+06
#        February   5.890557e+08  9.416163e+08    3.525606e+08     1.022426e+07
# ...

# %% [markdown]
# f. What are the top 5 product types?

# %%
spend.head()
# Out:
#   Customer      Month       Type     Amount  monthly Yearly
# 0       A1 2004-01-12  JEWELLERY  485470.80  January   2004
# 1       A1 2004-01-03      PETRO  410556.13  January   2004
# 2       A1 2004-01-15    CLOTHES   23740.46  January   2004
# 3       A1 2004-01-25       FOOD  484342.47  January   2004
# 4       A1 2005-01-17     CAMERA  369694.07  January   2005

# %%
spend['Type'].value_counts().head()
# Out:
# PETRO           200
# FOOD            160
# CAMERA          160
# AIR TICKET      147
# TRAIN TICKET    132
# Name: Type, dtype: int64

# %% [markdown]
# g. Which city is having maximum spend?

# %%
cust_spend.head(2)
# Out:
#   Customer   Age       City Product     Limit Company        Segment  \
# 0       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month       Type     Amount
# 0  12-Jan-04  JEWELLERY  485470.80
# 1   3-Jan-04      PETRO  410556.13

# %%
cust_spend.groupby(['City'])['Amount'].sum().sort_values(ascending=False)[0:1]
# Out:
# City
# COCHIN    45963513.5
# Name: Amount, dtype: float64

# %% [markdown]
# Therefore COCHIN city is having maximum spend of amount 45963513.5

# %% [markdown]
# h. Which age group is spending more money?

# %%
def age_grp(x):
    if (x>18 and x<26):
        return '18-25'
    elif (x>=26 and x<34):
        return '26-34'
    elif (x>=34 and x<42):
        return '34-42'
    elif (x>=42 and x<50):
        return '42-50'
    elif (x>=50 and x<58):
        return'50-58'
    elif (x>=58 and x<64):
        return '58-64'
    elif (x>=64 and x<70):
        return '64-70'
    elif (x>=70 and x<80):
        return '70-80'

# %%
cust_spend.head()
# Out:
#   Customer   Age       City Product     Limit Company        Segment  \
# 0       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month       Type     Amount
# 0  12-Jan-04  JEWELLERY  485470.80
# 1   3-Jan-04      PETRO  410556.13
# 2  15-Jan-04    CLOTHES   23740.46
# 3  25-Jan-04       FOOD  484342.47
# 4  17-Jan-05     CAMERA  369694.07

# %%
cust_spend['Age'] = cust_spend['Age'].astype(int)
cust_spend.head()
# Out:
#   Customer  Age       City Product     Limit Company        Segment  \
# 0       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 2       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 3       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 4       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month       Type     Amount
# 0  12-Jan-04  JEWELLERY  485470.80
# 1   3-Jan-04      PETRO  410556.13
# 2  15-Jan-04    CLOTHES   23740.46
# 3  25-Jan-04       FOOD  484342.47
# 4  17-Jan-05     CAMERA  369694.07

# %%
cust_spend['Age_group']= cust_spend.Age.apply(age_grp)

# %%
cust_spend.tail()
# Out:
#      Customer  Age        City   Product     Limit Company        Segment  \
# 1495      A96   54     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 1496      A97   58  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 1497      A98   51    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 1498      A99   35    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 1499     A100   36      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
#           Month        Type    Amount Age_group
# 1495  25-Jan-04        BIKE  54729.66     50-58
# 1496  12-Jan-04        AUTO   5000.00     58-64
# 1497   3-Jan-04    SHOPPING   5000.50     50-58
# 1498  15-Jan-04  AIR TICKET   5001.00     34-42
# 1499  25-Jan-04  BUS TICKET  50000.00     34-42

# %%
cust_spend.groupby(['Age_group'])['Amount'].sum().sort_values(ascending=False)
# Out:
# Age_group
# 42-50    45314602.81
# 34-42    39664773.38
# 50-58    30531870.07
# 26-34    29575196.78
# 70-80    28764364.83
# 18-25    24430197.30
# 58-64    12581956.97
# 64-70     8918123.09
# Name: Amount, dtype: float64

# %% [markdown]
# Therefor the Age_group 42-50 is spending more money

# %% [markdown]
# i. Who are the top 10 customers in terms of repayment?

# %%
cust_repay.head()
# Out:
#   Customer   Age       City Product     Limit Company        Segment  \
# 0       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month     Amount
# 0  12-Jan-04  495414.75
# 1   3-Jan-04  245899.02
# 2  15-Jan-04  259490.06
# 3  25-Jan-04  437555.12
# 4  17-Jan-05  165972.88

# %%
cust_repay.groupby('Customer')['Amount'].sum().sort_values(ascending=False).head(10)
# Out:
# Customer
# A61    10539142.91
# A60     9876290.74
# A13     9572000.66
# A43     8489871.46
# A45     8448334.87
# A12     8334760.16
# A14     7943268.63
# A44     7744730.12
# A39     7622483.30
# A42     7615460.86
# Name: Amount, dtype: float64

# %% [markdown]
# 3. Calculate the city wise spend on each product on yearly basis. Also include a graphical
# representation for the same.

# %%
cust_spend.head(2)
# Out:
#   Customer  Age       City Product     Limit Company        Segment  \
# 0       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month       Type     Amount Age_group
# 0  12-Jan-04  JEWELLERY  485470.80     70-80
# 1   3-Jan-04      PETRO  410556.13     70-80

# %%
cust_spend['Month']=pd.to_datetime(cust_spend['Month'])

# %%
cust_spend['Yearly']= cust_spend['Month'].apply(lambda x: dt.datetime.strftime(x, format='%Y'))
cust_spend.head()
# Out:
#   Customer  Age       City Product     Limit Company        Segment  \
# 0       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 2       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 3       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 4       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month       Type     Amount Age_group Yearly
# 0 2004-01-12  JEWELLERY  485470.80     70-80   2004
# 1 2004-01-03      PETRO  410556.13     70-80   2004
# 2 2004-01-15    CLOTHES   23740.46     70-80   2004
# 3 2004-01-25       FOOD  484342.47     70-80   2004
# 4 2005-01-17     CAMERA  369694.07     70-80   2005

# %%
city_wise_spend = pd.pivot_table(data=cust_spend, index=['City','Yearly'], columns='Product', values='Amount', aggfunc='sum')

# %%
city_wise_spend
# Out:
# Product                   Gold    Platimum      Silver
# City       Yearly
# BANGALORE  2004     9289878.54  1112732.30  1291852.58
#            2005    12892362.99   912284.97   830612.34
#            2006    12030611.09   685831.27  1415480.94
# BOMBAY     2004     6987853.53   897264.94   532089.03
#            2005     8983018.28   711804.94   508988.54
#            2006     7917144.31   972130.01  1092833.80
# CALCUTTA   2004     7477140.98  2037690.30   500006.00
#            2005    10303355.80  4434696.31   440147.06
#            2006    11167532.77  3589606.66  1157956.42
# CHENNAI    2004     1059618.50  3535652.38   282056.86
#            2005     3740945.58  5053956.32   377184.49
#            2006     2704288.62  5024923.40   350009.50
# COCHIN     2004     7315850.15  3419904.07   814229.62
#            2005    12110613.03  4960921.71   652269.38
#            2006    10499142.38  4920592.29  1269990.87
# DELHI      2004     2806495.00   283512.89   768172.30
# ...

# %%
city_wise_spend.plot(kind='bar', figsize=(15,5))
plt.ylabel('spend_amount')
plt.title('city_wise_spend')
# Out:
# Text(0.5, 1.0, 'city_wise_spend')

# %% [markdown]
# 4. Create graphs for
#
#  a. Monthly comparison of total spends, city wise

# %%
cust_spend.head()
# Out:
#   Customer  Age       City Product     Limit Company        Segment  \
# 0       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 2       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 3       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 4       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month       Type     Amount Age_group Yearly
# 0 2004-01-12  JEWELLERY  485470.80     70-80   2004
# 1 2004-01-03      PETRO  410556.13     70-80   2004
# 2 2004-01-15    CLOTHES   23740.46     70-80   2004
# 3 2004-01-25       FOOD  484342.47     70-80   2004
# 4 2005-01-17     CAMERA  369694.07     70-80   2005

# %%
cust_spend['Monthly']=cust_spend['Month'].apply(lambda x: dt.datetime.strftime(x, format = '%B'))

# %%
cust_spend.head(2)
# Out:
#   Customer  Age       City Product     Limit Company        Segment  \
# 0       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month       Type     Amount Age_group Yearly  Monthly
# 0 2004-01-12  JEWELLERY  485470.80     70-80   2004  January
# 1 2004-01-03      PETRO  410556.13     70-80   2004  January

# %%
month_city = cust_spend.groupby(['Monthly', 'City'])[['Amount']].sum()

# %%
month_city_spend = pd.pivot_table(data=cust_spend, index='City', columns='Monthly', values='Amount', aggfunc='sum')

# %%
month_city_spend
# Out:
# Monthly          April      August   December    February      January  \
# City
# BANGALORE   4207980.48   695061.95  422167.24  6734494.76   9041796.84
# BOMBAY      1873785.01  1066744.75  140040.71  4276988.30   5948993.33
# CALCUTTA    3457507.95  1548354.02   55001.50  8150545.61   9064864.90
# CHENNAI     2518656.99   305875.97  223628.27  4385815.95   4466961.36
# COCHIN      3882744.94  2317306.61  909533.05  5747886.38  11714373.54
# DELHI        777240.75   155402.16  842342.02  1494064.06   2714261.45
# PATNA       2338179.53   419383.64   50000.00  2353333.55   4916205.55
# TRIVANDRUM  1199293.45   453773.94  640922.26  2857123.89   3704336.99
#
# Monthly           July        June       March         May    November  \
# City
# BANGALORE   2228217.69  1330685.90  5362903.07  6383115.13  2260603.07
# BOMBAY       177726.32  1172594.97  5227850.50  3891945.60  2872049.40
# CALCUTTA    2234573.27  2293045.81  4939040.04  5578246.87  2078880.93
# ...

# %%
plt.style.use('ggplot')
month_city_spend.plot(kind='bar', figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='City'>

# %% [markdown]
#  b. Comparison of yearly spend on air tickets

# %%
spend.head(2)
# Out:
#   Customer      Month       Type     Amount  monthly Yearly
# 0       A1 2004-01-12  JEWELLERY  485470.80  January   2004
# 1       A1 2004-01-03      PETRO  410556.13  January   2004

# %%
air_ticket = spend.groupby(['Yearly','Type'])[['Amount']].sum().reset_index()
yearly_spend = air_ticket.loc[air_ticket['Type']=='AIR TICKET']
yearly_spend
# Out:
#    Yearly        Type       Amount
# 0    2004  AIR TICKET   8370914.59
# 15   2005  AIR TICKET  14495718.73
# 30   2006  AIR TICKET  10088812.10

# %%
plt.bar(yearly_spend['Yearly'], height=yearly_spend['Amount'],color = 'g')
plt.xlabel('Year')
plt.ylabel('Amount')
plt.title('Yearly_spend oN AIR TICKET')
plt.show()

# %% [markdown]
# c. Comparison of monthly spend for each product
#
# (look for any seasonalitythat exists in terms of spend)

# %%
cust_spend.head(2)
# Out:
#   Customer  Age       City Product     Limit Company        Segment  \
# 0       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A1   76  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month       Type     Amount Age_group Yearly  Monthly
# 0 2004-01-12  JEWELLERY  485470.80     70-80   2004  January
# 1 2004-01-03      PETRO  410556.13     70-80   2004  January

# %%
product_wise = pd.pivot_table(data=cust_spend, index='Product', columns='Monthly', values='Amount', aggfunc='sum')
product_wise
# Out:
# Monthly         April      August    December     February      January  \
# Product
# Gold      13170572.59  4954030.42  2332940.96  24779179.55  32413831.83
# Platimum   5182493.86  1714762.80   750156.19   9134054.58  14951578.51
# Silver     1902322.65   293109.82   200537.90   2087018.37   4206383.62
#
# Monthly         July        June        March          May    November  \
# Product
# Gold      5167416.37  6538862.64  19256972.48  21548169.76  9203267.46
# Platimum  1288156.26  2965712.71   7288837.68   8151926.49  2741618.42
# Silver     530153.72   689537.61   3909405.83   2140940.01   691102.63
#
# Monthly      October   September
# Product
# Gold      3018223.38  3816887.62
# Platimum   550275.04  1667840.84
# Silver     100001.50   442803.13

# %%
product_wise.plot(kind='bar', figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Product'>

# %% [markdown]
# Therefore highest sales are in junuary and february

# %% [markdown]
# 5. Write user defined PYTHON function to perform the following analysis:
#
# You need to find top 10 customers for each city in terms of their repayment amount by
# different products and by different time periods i.e. year or month. The user should be able
# to specify the product (Gold/Silver/Platinum) and time period (yearly or monthly) and the
# function should automatically take these inputs while identifying the top 10 customers.

# %%
cust_repay.head(2)
# Out:
#   Customer   Age       City Product     Limit Company        Segment  \
# 0       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month     Amount
# 0  12-Jan-04  495414.75
# 1   3-Jan-04  245899.02

# %%
cust_repay.dtypes
# Out:
# Customer     object
# Age         float64
# City         object
# Product      object
# Limit       float64
# Company      object
# Segment      object
# Month        object
# Amount      float64
# dtype: object

# %%
cust_repay['Month']=pd.to_datetime(cust_repay['Month'])

# %%
cust_repay.dtypes
# Out:
# Customer            object
# Age                float64
# City                object
# Product             object
# Limit              float64
# Company             object
# Segment             object
# Month       datetime64[ns]
# Amount             float64
# dtype: object

# %%
cust_repay['Monthly']=cust_repay['Month'].apply(lambda x: dt.datetime.strftime(x, "%B"))
cust_repay['Yearly']=cust_repay['Month'].apply(lambda x: dt.datetime.strftime(x, "%Y"))

# %%
cust_repay.head(2)
# Out:
#   Customer   Age       City Product     Limit Company        Segment  \
# 0       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#        Month     Amount  Monthly Yearly
# 0 2004-01-12  495414.75  January   2004
# 1 2004-01-03  245899.02  January   2004

# %%
cust_repay.Product.unique()
# Out:
# array(['Gold', 'Silver', 'Platimum'], dtype=object)

# %%
def Report(product, timeperiod):
    if product.lower()=='gold' and timeperiod.lower()=='monthly':
        pivot = cust_repay.pivot_table(index=['Product','City','Customer'],columns='Monthly', values='Amount', aggfunc='sum')
        result = pivot.loc['Gold']
    elif product.lower()=='gold' and timeperiod.lower()=='yearly':
        pivot = cust_repay.pivot_table(index=['Product','City','Customer'],columns='Yearly', values='Amount', aggfunc='sum')
        result = pivot.loc['Gold']
    elif product.lower()=='silver' and timeperiod.lower()=='monthly':
        pivot = cust_repay.pivot_table(index=['Product','City','Customer'],columns='Monthly', values='Amount', aggfunc='sum')
        result = pivot.loc['Silver']
    elif product.lower()=='silver' and timeperiod.lower()=='yearly':
        pivot = cust_repay.pivot_table(index=['Product','City','Customer'],columns='Yearly', values='Amount', aggfunc='sum')
        result = pivot.loc['Silver']
    elif product.lower()=='Platimum' and timeperiod.lower()=='monthly':
        pivot = cust_repay.pivot_table(index=['Product','City','Customer'],columns='Monthly', values='Amount', aggfunc='sum')
        result = pivot.loc['Platimum'] 
    elif product.lower()=='Platimum' and timeperiod.lower()=='yearly':
        pivot = cust_repay.pivot_table(index=['Product','City','Customer'],columns='Yearly', values='Amount', aggfunc='sum')
        result = pivot.loc['Platimum']
    return result

# %%
Report('silver','yearly')
# Out:
# Yearly                     2004        2005        2006
# City       Customer
# BANGALORE  A18        491592.71   638296.41   700000.00
#            A23        664965.71  1000010.00   872925.32
#            A59        676557.50   427247.08   600018.00
#            A72        100000.00         NaN         NaN
#            A76              NaN   265619.05         NaN
#            A77              NaN         NaN     3159.62
# BOMBAY     A22        953419.47  1141542.81   945271.83
#            A75              NaN   100003.00         NaN
#            A80              NaN         NaN   481205.64
# CALCUTTA   A2         400000.00   410274.00   200000.00
#            A58        533815.62   540173.85   411640.17
#            A73              NaN   100001.00         NaN
#            A78              NaN         NaN    55344.81
#            A87              NaN         NaN   100003.00
# CHENNAI    A85              NaN         NaN   100001.00
# ...

# %%
Report('gold','monthly')
# Out:
# Monthly                   April     August   December    February     January  \
# City       Customer
# BANGALORE  A1         508949.16        NaN        NaN   781873.80  2407806.29
#            A13        494392.40  873304.51        NaN  2049808.15  2014186.98
#            A14        812582.20  198623.13  388821.96  1482923.34   993114.87
#            A30        425694.16        NaN        NaN  1321469.80   608066.49
#            A43        612541.80        NaN        NaN   763846.93  1978038.15
#            A63              NaN        NaN        NaN         NaN   372179.26
#            A81              NaN        NaN        NaN         NaN         NaN
#            A88              NaN        NaN        NaN         NaN         NaN
#            A92        459105.69        NaN        NaN         NaN         NaN
# BOMBAY     A12        601326.07  120471.17        NaN  1978117.59  1220387.18
#            A17        391463.29   98341.04  479227.30   374865.01   761645.74
# ...
